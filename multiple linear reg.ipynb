# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

dataset = pd.read_csv(r"C:\Users\Ahsan\Downloads\multiple_linear_regression_data.csv")
dataset.head(3)
# Out:
#    Age  Experience  Salary
# 0   25           1   40000
# 1   28           3   50000
# 2   30           4   55000

# %%
dataset.isnull().sum()
# Out:
# Age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
x = dataset.iloc[:, :-1]
y = dataset["Salary"]

# %%
x.ndim
# Out:
# 2

# %%
dataset.shape
# Out:
# (10, 3)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)*100
# Out:
# 97.85277887595805

# %%
# y1=m1x1+m2x2+c

# %%
lr.coef_
# Out:
# array([-1705.95309681,  5692.42333133])

# %%
lr.intercept_
# Out:
# np.float64(80395.36981358992)

# %%
# Assuming X_test is a pandas DataFrame with columns 'Age' and 'Experience'
y_pnd = (-1705.95309681 * x_test['Age'] 
         + 5692.42333133 * x_test['Experience'] 
         + 80395.36981358992)

print(y_pnd)
# Out:
# 8    89031.569453
# 1    49705.953097
# dtype: float64
